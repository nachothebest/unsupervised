# %%
#!pip install --trusted-host pypi.org --trusted-host files.pythonhosted.org ydata-profiling
#!pip install missingno --trusted-host pypi.org --trusted-host files.pythonhosted.org

import pandas as pd
import warnings
import plotly.graph_objects as go
import plotly.express as px
import ipywidgets as widgets
from IPython.display import display, clear_output
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
from sklearn.preprocessing import LabelEncoder
from statsmodels.stats.outliers_influence import variance_inflation_factor
from ydata_profiling import ProfileReport
import missingno as msno
# Out:
# Collecting missingno
#   Downloading missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (from missingno) (1.26.4)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.12/site-packages (from missingno) (3.8.4)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.12/site-packages (from missingno) (1.13.1)
# Requirement already satisfied: seaborn in /opt/anaconda3/lib/python3.12/site-packages (from missingno) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->missingno) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->missingno) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->missingno) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->missingno) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->missingno) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->missingno) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in /opt/anaconda3/lib/python3.12/site-packages (from seaborn->missingno) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.2->seaborn->missingno) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.2->seaborn->missingno) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Installing collected packages: missingno
# Successfully installed missingno-0.5.2

# %%
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

archivo_2020_1 = 'data/Saber_11__2020-1_20240828.csv'
archivo_2020_2 = 'data/Saber_11__2020-2_20240828.csv'

saber_2020_1 = pd.read_csv(archivo_2020_1)
saber_2020_2 = pd.read_csv(archivo_2020_2)


saber_2020 = pd.concat([saber_2020_1, saber_2020_2], ignore_index=True)

saber_2020.head()
# Out:
#   ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO ESTU_FECHANACIMIENTO  \
# 0                 CC          COLOMBIA           F           01/01/1985
# 1                 CC          COLOMBIA           F           01/01/1995
# 2                 CC          COLOMBIA           F           01/01/1997
# 3                 CC          COLOMBIA           F           01/01/2001
# 4                 CC          COLOMBIA           F           02/01/2001
#
#    PERIODO  ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_PAIS_RESIDE ESTU_TIENEETNIA  \
# 0    20201  SB11202010045555      ESTUDIANTE         COLOMBIA              No
# 1    20201  SB11202010045719      ESTUDIANTE         COLOMBIA              No
# 2    20201  SB11202010070662      ESTUDIANTE         COLOMBIA              Si
# 3    20201  SB11202010069926      ESTUDIANTE         COLOMBIA              No
# 4    20201  SB11202010023181      ESTUDIANTE         COLOMBIA              No
#
#   ESTU_DEPTO_RESIDE  ESTU_COD_RESIDE_DEPTO ESTU_MCPIO_RESIDE  \
# 0             CESAR                   20.0         SAN DIEGO
# 1            NARIÑO                   52.0           IPIALES
# 2             CAUCA                   19.0            TOTORÓ
# 3          PUTUMAYO                   86.0             MOCOA
# 4         RISARALDA                   66.0           PEREIRA
#
#    ESTU_COD_RESIDE_MCPIO FAMI_ESTRATOVIVIENDA FAMI_PERSONASHOGAR  \
# 0                20750.0            Estrato 1              5 a 6
# 1                52356.0                  NaN                NaN
# 2                19824.0            Estrato 1              3 a 4
# 3                86001.0            Estrato 1              1 a 2
# 4                66001.0            Estrato 6              3 a 4
#
#   FAMI_CUARTOSHOGAR                   FAMI_EDUCACIONPADRE  \
# 0               Uno                   Primaria incompleta
# 1               NaN                                   NaN
# 2            Cuatro  Secundaria (Bachillerato) incompleta
# 3               Uno        Técnica o tecnológica completa
# 4            Cuatro        Educación profesional completa
#
#                     FAMI_EDUCACIONMADRE  \
# 0                   Primaria incompleta
# 1                                   NaN
# 2  Secundaria (Bachillerato) incompleta
# 3        Educación profesional completa
# 4    Secundaria (Bachillerato) completa
#
#                               FAMI_TRABAJOLABORPADRE  \
# 0          Trabaja en el hogar, no trabaja o estudia
# 1                                                NaN
# 2          Trabaja en el hogar, no trabaja o estudia
# 3  Es dueño de un negocio grande, tiene un cargo ...
# 4  Trabaja como profesional (por ejemplo médico, ...
#
#                               FAMI_TRABAJOLABORMADRE FAMI_TIENEINTERNET  \
# 0  Trabaja por cuenta propia (por ejemplo plomero...                 No
# 1                                                NaN                NaN
# 2          Trabaja en el hogar, no trabaja o estudia                 No
# 3  Trabaja como profesional (por ejemplo médico, ...                 Si
# 4          Trabaja en el hogar, no trabaja o estudia                 Si
#
#   FAMI_TIENESERVICIOTV FAMI_TIENECOMPUTADOR FAMI_TIENELAVADORA  \
# 0                   No                   No                 No
# 1                  NaN                  NaN                NaN
# 2                   No                   No                 No
# 3                   No                   Si                 Si
# 4                   Si                   Si                 Si
#
#   FAMI_TIENEHORNOMICROOGAS FAMI_TIENEAUTOMOVIL FAMI_TIENEMOTOCICLETA  \
# 0                       No                  No                    No
# 1                      NaN                 NaN                   NaN
# 2                       No                  No                    No
# 3                       No                  No                    Si
# 4                       Si                  Si                    No
#
#   FAMI_TIENECONSOLAVIDEOJUEGOS   FAMI_NUMLIBROS      FAMI_COMELECHEDERIVADOS  \
# 0                           No    0 A 10 LIBROS       1 o 2 veces por semana
# 1                          NaN              NaN                          NaN
# 2                           No    0 A 10 LIBROS       1 o 2 veces por semana
# 3                           No   11 A 25 LIBROS       1 o 2 veces por semana
# 4                           No  26 A 100 LIBROS  Todos o casi todos los días
#
#     FAMI_COMECARNEPESCADOHUEVO FAMI_COMECEREALFRUTOSLEGUMBRE  \
# 0       1 o 2 veces por semana   Todos o casi todos los días
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3       3 a 5 veces por semana        1 o 2 veces por semana
# 4  Todos o casi todos los días        3 a 5 veces por semana
#
#   FAMI_SITUACIONECONOMICA ESTU_DEDICACIONLECTURADIARIA  \
# 0                   Mejor   No leo por entretenimiento
# 1                     NaN                          NaN
# 2                   Igual           30 minutos o menos
# 3                   Igual           30 minutos o menos
# 4                   Igual   No leo por entretenimiento
#
#   ESTU_DEDICACIONINTERNET ESTU_HORASSEMANATRABAJA ESTU_TIPOREMUNERACION  \
# 0      No Navega Internet         Más de 30 horas       Si, en efectivo
# 1                     NaN                     NaN                   NaN
# 2      No Navega Internet     Entre 11 y 20 horas       Si, en efectivo
# 3       Entre 1 y 3 horas     Entre 11 y 20 horas       Si, en efectivo
# 4          Más de 3 horas                       0                    No
#
#    COLE_CODIGO_ICFES  COLE_COD_DANE_ESTABLECIMIENTO  \
# 0              57372                   120750000415
# 1             177618                   352356001951
# 2             135301                   319001004669
# 3             155739                   386001003939
# 4              77776                   366001003814
#
#                          COLE_NOMBRE_ESTABLECIMIENTO COLE_GENERO  \
# 0                      I.E. MANUEL RODRIGUEZ TORICES       MIXTO
# 1              INSTITUTO DE EDUCACIÓN TECNICA INESUR       MIXTO
# 2  COORPORACION EDUCATIVA DEL SUR OCCIDENTE COLOM...       MIXTO
# 3       NUEVO INSTITUTO DE APRENDIZAJE SURCOLOMBIANO       MIXTO
# 4                           COL FUNDACION LIC INGLES       MIXTO
#
#   COLE_NATURALEZA COLE_CALENDARIO COLE_BILINGUE      COLE_CARACTER  \
# 0         OFICIAL               A             S  TÉCNICO/ACADÉMICO
# 1      NO OFICIAL               A           NaN                NaN
# 2      NO OFICIAL            OTRO           NaN          ACADÉMICO
# 3      NO OFICIAL               A           NaN  TÉCNICO/ACADÉMICO
# 4      NO OFICIAL               B             S          ACADÉMICO
#
#    COLE_COD_DANE_SEDE                                   COLE_NOMBRE_SEDE  \
# 0        120750000415                      I.E. MANUEL RODRIGUEZ TORICES
# 1        352356001951  INSTITUTO DE EDUCACIÓN TECNICA INESUR - SEDE P...
# 2        319001004669  COORPORACION EDUCATIVA DEL SUR OCCIDENTE COLOM...
# 3        386001003939  NUEVO INSTITUTO DE APRENDIZAJE SURCOLOMBIANO -...
# 4        366001003814                           COL FUNDACION LIC INGLES
#
#   COLE_SEDE_PRINCIPAL COLE_AREA_UBICACION COLE_JORNADA  \
# 0                   S              URBANO        NOCHE
# 1                   S              URBANO     SABATINA
# 2                   S              URBANO       MAÑANA
# 3                   S              URBANO     SABATINA
# 4                   S               RURAL     COMPLETA
#
#    COLE_COD_MCPIO_UBICACION COLE_MCPIO_UBICACION  COLE_COD_DEPTO_UBICACION  \
# 0                     20750            SAN DIEGO                        20
# 1                     52356              IPIALES                        52
# 2                     19001              POPAYÁN                        19
# 3                     86001                MOCOA                        86
# 4                     66001              PEREIRA                        66
#
#   COLE_DEPTO_UBICACION ESTU_PRIVADO_LIBERTAD  ESTU_COD_MCPIO_PRESENTACION  \
# 0                CESAR                     N                      20001.0
# 1               NARIÑO                     N                      52356.0
# 2                CAUCA                     N                      19001.0
# 3             PUTUMAYO                     N                      86001.0
# 4            RISARALDA                     N                      66001.0
#
#   ESTU_MCPIO_PRESENTACION ESTU_DEPTO_PRESENTACION  \
# 0              VALLEDUPAR                   CESAR
# 1                 IPIALES                  NARIÑO
# 2                 POPAYÁN                   CAUCA
# 3                   MOCOA                PUTUMAYO
# 4                 PEREIRA               RISARALDA
#
#    ESTU_COD_DEPTO_PRESENTACION  PUNT_LECTURA_CRITICA  \
# 0                         20.0                    39
# 1                         52.0                    41
# 2                         19.0                    37
# 3                         86.0                    38
# 4                         66.0                    58
#
#    PERCENTIL_LECTURA_CRITICA  DESEMP_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# 0                          6                       2                32
# 1                          7                       2                41
# 2                          4                       2                36
# 3                          5                       2                42
# 4                         42                       3                50
#
#    PERCENTIL_MATEMATICAS  DESEMP_MATEMATICAS  PUNT_C_NATURALES  \
# 0                      4                   1                35
# 1                     12                   2                39
# 2                      7                   2                33
# 3                     13                   2                38
# 4                     25                   2                50
#
#    PERCENTIL_C_NATURALES  DESEMP_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  \
# 0                      6                   1                        24
# 1                     10                   1                        44
# 2                      4                   1                        24
# 3                     10                   1                        33
# 4                     32                   2                        53
#
#    PERCENTIL_SOCIALES_CIUDADANAS  DESEMP_SOCIALES_CIUDADANAS  PUNT_INGLES  \
# 0                              1                           1         36.0
# 1                             23                           2         30.0
# 2                              1                           1         30.0
# 3                              7                           1         37.0
# 4                             42                           2         80.0
#
#    PERCENTIL_INGLES DESEMP_INGLES  PUNT_GLOBAL  PERCENTIL_GLOBAL  \
# 0                 7            A-          164               2.0
# 1                 3            A-          202              10.0
# 2                 3            A-          162               2.0
# 3                 8            A-          188               6.0
# 4                80            B+          274              39.0
#
#    ESTU_ESTADOINVESTIGACION         ESTU_GENERACION-E  ESTU_INSE_INDIVIDUAL  \
# 0  VALIDEZ OFICINA JURÍDICA  GENERACION E - GRATUIDAD                   NaN
# 1                  PUBLICAR  GENERACION E - GRATUIDAD                   NaN
# 2                  PUBLICAR  GENERACION E - GRATUIDAD                   NaN
# 3                  PUBLICAR                        NO                   NaN
# 4                  PUBLICAR                        NO                   NaN
#
#    ESTU_NSE_INDIVIDUAL  ESTU_NSE_ESTABLECIMIENTO
# 0                  NaN                       NaN
# 1                  NaN                       NaN
# 2                  NaN                       NaN
# 3                  NaN                       NaN
# 4                  NaN                       NaN

# %%
missing_summary = pd.DataFrame({
    'Missing Count': saber_2020.isnull().sum(),
    'Missing Percentage': (saber_2020.isnull().sum() / len(saber_2020)) * 100
})

# Filter to show only columns with missing values
missing_summary = missing_summary[missing_summary['Missing Count'] > 0]

# Sort by the number of missing values
missing_summary = missing_summary.sort_values(by='Missing Count', ascending=False)

# Display the summary
display(missing_summary)
# Out:
#                                Missing Count  Missing Percentage
# COLE_BILINGUE                          85622           16.456054
# ESTU_NSE_INDIVIDUAL                    29380            5.646666
# ESTU_INSE_INDIVIDUAL                   29380            5.646666
# FAMI_COMECEREALFRUTOSLEGUMBRE          21811            4.191948
# FAMI_TIENECOMPUTADOR                   21616            4.154470
# FAMI_TRABAJOLABORPADRE                 21147            4.064331
# FAMI_TIENEAUTOMOVIL                    19264            3.702430
# ESTU_TIPOREMUNERACION                  19104            3.671678
# FAMI_TRABAJOLABORMADRE                 19059            3.663030
# FAMI_TIENECONSOLAVIDEOJUEGOS           18929            3.638044
# FAMI_TIENEHORNOMICROOGAS               18579            3.570776
# FAMI_TIENEMOTOCICLETA                  18537            3.562704
# FAMI_ESTRATOVIVIENDA                   18510            3.557515
# ESTU_HORASSEMANATRABAJA                18404            3.537142
# FAMI_SITUACIONECONOMICA                17764            3.414138
# FAMI_TIENELAVADORA                     17659            3.393958
# FAMI_CUARTOSHOGAR                      17278            3.320732
# FAMI_TIENESERVICIOTV                   16983            3.264035
# FAMI_COMECARNEPESCADOHUEVO             16841            3.236743
# FAMI_PERSONASHOGAR                     16580            3.186580
# ESTU_DEDICACIONINTERNET                16179            3.109510
# ESTU_DEDICACIONLECTURADIARIA           16013            3.077606
# FAMI_NUMLIBROS                         15606            2.999383
# ESTU_NSE_ESTABLECIMIENTO               15484            2.975935
# FAMI_COMELECHEDERIVADOS                15265            2.933845
# FAMI_TIENEINTERNET                     15194            2.920199
# COLE_CARACTER                          15105            2.903094
# FAMI_EDUCACIONMADRE                    15030            2.888679
# FAMI_EDUCACIONPADRE                    14539            2.794312
# ESTU_TIENEETNIA                         3757            0.722074
# ESTU_COD_RESIDE_MCPIO                    766            0.147221
# ESTU_MCPIO_RESIDE                        766            0.147221
# ESTU_DEPTO_RESIDE                        766            0.147221
# ESTU_COD_RESIDE_DEPTO                    766            0.147221
# PUNT_INGLES                              370            0.071112
# ESTU_COD_MCPIO_PRESENTACION              208            0.039976
# ESTU_COD_DEPTO_PRESENTACION              208            0.039976
# ESTU_DEPTO_PRESENTACION                  208            0.039976
# ESTU_MCPIO_PRESENTACION                  208            0.039976
# PERCENTIL_GLOBAL                          36            0.006919
# ESTU_GENERO                                9            0.001730

# %%
profile = ProfileReport(saber_2020, title="Exploración Datos Pruebas Saber", explorative=True)

# Save the report to an HTML file
profile.to_file("estadisticasDescriptivasSaber2020.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
